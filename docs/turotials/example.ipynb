# %% [markdown]
# # Practical 1: Power Balancing for a Local Community

# %% [markdown]
# ```{warning}
# This tutorial serves as an example on how to include Jupyter notebooks into the documentation. The tooling required to reproduce it is not part of the `illuminator` yet.
# ```

# %% [markdown]
# #### Importing the needed packages
# The first step in every python notebook is to install the needed packages (e.g. [`pandas`](https://pandas.pydata.org/docs/user_guide/index.html) for data management) as well as functions and classes from external scripts. For this practical assignment the class simulation_creator_Balancing is used to simplify the set-up of simulations of different energy systems.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import functions_T1

#Importing the Simulation script
import sys
import os
current_dir = os.getcwd()
parent_dir = os.path.abspath(os.path.join(current_dir, os.pardir))
sys.path.insert(0, parent_dir)
from simulation_creator_T1_Balancing import simulation_creator_Balancing

# %% [markdown]
# In this tutorial a neighbourhood is connected to the grid as sketched below. For a typical day in the year the neighbourhood has a given demand profile (load_data.txt file). The given load data is for a year and is given in 15 minute intervals. This electricity demand must be fulfilled.

# %% [markdown]
# #### Task 1: Load Profile for a Neighbourhood
#
# In the first task entails the neighbourhood takes all electricity from the grid. The demand of the neighbourhood can be visualized in a load profile for a day of choice. The following python code plots a specified day based on the given load data and the specified number of houses in the neighbourhood. Electricity from the grid comes from various sources. The energy mix of the Netherlands can be found under https://www.iea.org/countries/the-netherlands/energy-mix. In the code the load data is first saved in a pandas dataframe and it is ensured that the index is the time. Then the day is chosen and a function is called to plot the load data on this day. Run the code and describe what you can see in the plot. You can vary the day for which you want to plot the load with the day_of_year parameter.

# %% [markdown]
# ![T1_basecase](Graphics_T1/T1_basecase.png)

# %%
load_df = pd.read_csv('../Scenarios/load_data.txt', delimiter=',', skiprows=1)
load_df['time'] = pd.to_datetime(load_df['time'])
load_df.set_index('time', inplace=True)

#choose which day of the year to plot
day_of_year = "2012-06-01"
number_houses = 5 
plot_load_base_case = functions_T1.plot_load_profile(load_df, day_of_year, number_houses)

# %% [markdown]
# The community implements small scale PV and wind power plants to become more autonomous. Now first the supply from the local renewable energy sources is used to cover the demand in the community. The residual load is then supplied by the grid. In case of excess renewable generation the generated electricity is fed into the grid.

# %% [markdown]
# ![T1_RES_case](Graphics_T1/T1_RES_case.png)

# %% [markdown]
# #### Task 2: Neighbourhood with local RES
#
# In the below presented code the neighbourhood is set up by defining the key components (here Wind, PV and Load). After defining number of houses and specifications of the installed wind and solar energy in the neighbourhood, a simulation is created and started with the simulation_creator_Balancing class. Finally, the summarise_results function
#
# Run the following python code and look at the resulting residual load plot. Describe the plot and compare it to the results from task 1. Vary the installed PV and Wind power as well as the number of houses in the neighbourhood. Describe your findings.

# %%
# %%capture
day_of_year = "2012-06-01"

#Component Set Up
Components_RES_case = pd.Series(['Wind', 'PV', 'Load'])

#Input Data Simulation
number_houses = 5    #demand specs

# Note: PV Inputs are currently in W! -> need to change?
pv_inputs = {'Module_area': 1.26, 'cap':500, 'Power_output_at_STC': 250,'peak_power':0.6}
# Optional PV inputs with examples: 'NOCT': 44, 'Module_Efficiency': 0.198, 'Irradiance_at_NOCT': 800,
# 'Power_output_at_STC': 250,'peak_power':600, 'm_tilt':14,'m_az':180

wind_inputs = {'p_rated':0.3, 'cp':0.40}
#Options for Wind inputs with example values: 'p_rated':300, 'u_rated':10.3, 
# 'u_cutin':2.8, 'u_cutout':25, 'cp':0.40, 'diameter':22, 'output_type':'power'}

RES_case_simulation = simulation_creator_Balancing(Components_RES_case, day_of_year,number_houses,pv_inputs, wind_inputs);
# Out:
# 2024-11-01 12:38:23.276 | INFO     | mosaik.scenario:start:255 - Starting "Controller" as "Controller-0" ...
# 2024-11-01 12:38:23.295 | INFO     | mosaik.scenario:start:255 - Starting "Collector" as "Collector-0" ...
# 2024-11-01 12:38:23.320 | INFO     | mosaik.scenario:start:255 - Starting "CSVB" as "CSVB-0" ...
# 2024-11-01 12:38:24.178 | INFO     | mosaik.scenario:start:255 - Starting "Wind" as "Wind-0" ...
# 2024-11-01 12:38:24.197 | INFO     | mosaik.scenario:start:255 - Starting "CSVB" as "CSVB-1" ...
# 2024-11-01 12:38:25.074 | INFO     | mosaik.scenario:start:255 - Starting "PV" as "PV-0" ...
# 2024-11-01 12:38:25.092 | INFO     | mosaik.scenario:start:255 - Starting "CSVB" as "CSVB-2" ...
# 2024-11-01 12:38:25.839 | INFO     | mosaik.scenario:start:255 - Starting "Load" as "Load-0" ...
# 2024-11-01 12:38:25.850 | WARNING  | mosaik.scenario:_check_attributes_values:730 - A connection between persistent and trigger attributes is not recommended.This might cause problems in the simulation!
# 2024-11-01 12:38:26.111 | INFO     | mosaik.scenario:run:532 - Starting simulation.
# 2024-11-01 12:38:27.776 | INFO     | mosaik.scenario:run:576 - Simulation finished successfully.

# %% [markdown]
# To visualize the results from the simulation run the summarize_results() function below each time you modify the inputs:

# %%
RES_case_simulation.summarize_results()
# Out:
# <style type="text/css">
# #T_36cf6_row0_col0, #T_36cf6_row0_col1, #T_36cf6_row0_col2, #T_36cf6_row0_col3, #T_36cf6_row1_col0, #T_36cf6_row1_col1, #T_36cf6_row1_col2, #T_36cf6_row1_col3, #T_36cf6_row2_col0, #T_36cf6_row2_col1, #T_36cf6_row2_col2, #T_36cf6_row2_col3, #T_36cf6_row3_col0, #T_36cf6_row3_col1, #T_36cf6_row3_col2, #T_36cf6_row3_col3, #T_36cf6_row4_col0, #T_36cf6_row4_col1, #T_36cf6_row4_col2, #T_36cf6_row4_col3, #T_36cf6_row5_col0, #T_36cf6_row5_col1, #T_36cf6_row5_col2, #T_36cf6_row5_col3, #T_36cf6_row6_col0, #T_36cf6_row6_col1, #T_36cf6_row6_col2, #T_36cf6_row6_col3, #T_36cf6_row7_col0, #T_36cf6_row7_col1, #T_36cf6_row7_col2, #T_36cf6_row7_col3, #T_36cf6_row8_col0, #T_36cf6_row8_col1, #T_36cf6_row8_col2, #T_36cf6_row8_col3, #T_36cf6_row9_col0, #T_36cf6_row9_col1, #T_36cf6_row9_col2, #T_36cf6_row9_col3, #T_36cf6_row10_col0, #T_36cf6_row10_col1, #T_36cf6_row10_col2, #T_36cf6_row10_col3, #T_36cf6_row11_col0, #T_36cf6_row11_col1, #T_36cf6_row11_col2, #T_36cf6_row11_col3, #T_36cf6_row12_col0, #T_36cf6_row12_col1, #T_36cf6_row12_col2, #T_36cf6_row12_col3, #T_36cf6_row13_col0, #T_36cf6_row13_col1, #T_36cf6_row13_col2, #T_36cf6_row13_col3, #T_36cf6_row14_col0, #T_36cf6_row14_col1, #T_36cf6_row14_col2, #T_36cf6_row14_col3, #T_36cf6_row15_col0, #T_36cf6_row15_col1, #T_36cf6_row15_col2, #T_36cf6_row15_col3, #T_36cf6_row16_col0, #T_36cf6_row16_col1, #T_36cf6_row16_col2, #T_36cf6_row16_col3, #T_36cf6_row17_col0, #T_36cf6_row17_col1, #T_36cf6_row17_col2, #T_36cf6_row17_col3, #T_36cf6_row18_col0, #T_36cf6_row18_col1, #T_36cf6_row18_col2, #T_36cf6_row18_col3, #T_36cf6_row19_col0, #T_36cf6_row19_col1, #T_36cf6_row19_col2, #T_36cf6_row19_col3, #T_36cf6_row20_col0, #T_36cf6_row20_col1, #T_36cf6_row20_col2, #T_36cf6_row20_col3, #T_36cf6_row21_col0, #T_36cf6_row21_col1, #T_36cf6_row21_col2, #T_36cf6_row21_col3, #T_36cf6_row22_col0, #T_36cf6_row22_col1, #T_36cf6_row22_col2, #T_36cf6_row22_col3, #T_36cf6_row23_col0, #T_36cf6_row23_col1, #T_36cf6_row23_col2, #T_36cf6_row23_col3 {
#   background-color: #f9f9f9;
#   border-color: black;
#   border-width: 1px;
#   border-style: solid;
#   color: black;
#   font-family: Arial;
#   text-align: center;
# }
# </style>
# <table id="T_36cf6">
#   <caption>Hourly Simulation results</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_36cf6_level0_col0" class="col_heading level0 col0" >Residual Load</th>
#       <th id="T_36cf6_level0_col1" class="col_heading level0 col1" >PV Generation (kW)</th>
#       <th id="T_36cf6_level0_col2" class="col_heading level0 col2" >Wind Generation (kW)</th>
#       <th id="T_36cf6_level0_col3" class="col_heading level0 col3" >Load Demand (kW)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >date</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_36cf6_level0_row0" class="row_heading level0 row0" >2012-06-01 00:00:00</th>
#       <td id="T_36cf6_row0_col0" class="data row0 col0" >0.860406</td>
#       <td id="T_36cf6_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_36cf6_row0_col2" class="data row0 col2" >1.075314</td>
#       <td id="T_36cf6_row0_col3" class="data row0 col3" >1.935720</td>
#     </tr>
#     <tr>
#       <th id="T_36cf6_level0_row1" class="row_heading level0 row1" >2012-06-01 01:00:00</th>
#       <td id="T_36cf6_row1_col0" class="data row1 col0" >0.861353</td>
#       <td id="T_36cf6_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_36cf6_row1_col2" class="data row1 col2" >0.817498</td>
#       <td id="T_36cf6_row1_col3" class="data row1 col3" >1.678851</td>
#     </tr>
#     <tr>
#       <th id="T_36cf6_level0_row2" class="row_heading level0 row2" >2012-06-01 02:00:00</th>
#       <td id="T_36cf6_row2_col0" class="data row2 col0" >0.073390</td>
#       <td id="T_36cf6_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_36cf6_row2_col2" class="data row2 col2" >0.790373</td>
#       <td id="T_36cf6_row2_col3" class="data row2 col3" >0.863764</td>
#     </tr>
#     <tr>
#       <th id="T_36cf6_level0_row3" class="row_heading level0 row3" >2012-06-01 03:00:00</th>
#       <td id="T_36cf6_row3_col0" class="data row3 col0" >-0.340568</td>
#       <td id="T_36cf6_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_36cf6_row3_col2" class="data row3 col2" >0.784690</td>
#       <td id="T_36cf6_row3_col3" class="data row3 col3" >0.444122</td>
#     </tr>
#     <tr>
#       <th id="T_36cf6_level0_row4" class="row_heading level0 row4" >2012-06-01 04:00:00</th>
#       <td id="T_36cf6_row4_col0" class="data row4 col0" >0.060149</td>
#       <td id="T_36cf6_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_36cf6_row4_col2" class="data row4 col2" >0.349552</td>
#       <td id="T_36cf6_row4_col3" class="data row4 col3" >0.409701</td>
#     </tr>
#     <tr>
#       <th id="T_36cf6_level0_row5" class="row_heading level0 row5" >2012-06-01 05:00:00</th>
#       <td id="T_36cf6_row5_col0" class="data row5 col0" >-0.011290</td>
#       <td id="T_36cf6_row5_col1" class="data row5 col1" >0.261893</td>
#       <td id="T_36cf6_row5_col2" class="data row5 col2" >0.387379</td>
#       <td id="T_36cf6_row5_col3" class="data row5 col3" >0.637982</td>
#     </tr>
#     <tr>
#       <th id="T_36cf6_level0_row6" class="row_heading level0 row6" >2012-06-01 06:00:00</th>
#       <td id="T_36cf6_row6_col0" class="data row6 col0" >-0.185529</td>
#       <td id="T_36cf6_row6_col1" class="data row6 col1" >0.511917</td>
#       <td id="T_36cf6_row6_col2" class="data row6 col2" >0.589874</td>
#       <td id="T_36cf6_row6_col3" class="data row6 col3" >0.916262</td>
#     </tr>
#     <tr>
#       <th id="T_36cf6_level0_row7" class="row_heading level0 row7" >2012-06-01 07:00:00</th>
#       <td id="T_36cf6_row7_col0" class="data row7 col0" >-0.194884</td>
#       <td id="T_36cf6_row7_col1" class="data row7 col1" >0.922958</td>
#       <td id="T_36cf6_row7_col2" class="data row7 col2" >0.234929</td>
#       <td id="T_36cf6_row7_col3" class="data row7 col3" >0.963003</td>
#     </tr>
#     <tr>
#       <th id="T_36cf6_level0_row8" class="row_heading level0 row8" >2012-06-01 08:00:00</th>
#       <td id="T_36cf6_row8_col0" class="data row8 col0" >0.248383</td>
#       <td id="T_36cf6_row8_col1" class="data row8 col1" >0.714950</td>
#       <td id="T_36cf6_row8_col2" class="data row8 col2" >0.172093</td>
#       <td id="T_36cf6_row8_col3" class="data row8 col3" >1.135426</td>
#     </tr>
#     <tr>
#       <th id="T_36cf6_level0_row9" class="row_heading level0 row9" >2012-06-01 09:00:00</th>
#       <td id="T_36cf6_row9_col0" class="data row9 col0" >-0.097137</td>
#       <td id="T_36cf6_row9_col1" class="data row9 col1" >0.825907</td>
#       <td id="T_36cf6_row9_col2" class="data row9 col2" >0.252955</td>
#       <td id="T_36cf6_row9_col3" class="data row9 col3" >0.981725</td>
#     </tr>
#     <tr>
#       <th id="T_36cf6_level0_row10" class="row_heading level0 row10" >2012-06-01 10:00:00</th>
#       <td id="T_36cf6_row10_col0" class="data row10 col0" >0.301116</td>
#       <td id="T_36cf6_row10_col1" class="data row10 col1" >1.324526</td>
#       <td id="T_36cf6_row10_col2" class="data row10 col2" >0.518773</td>
#       <td id="T_36cf6_row10_col3" class="data row10 col3" >2.144415</td>
#     </tr>
#     <tr>
#       <th id="T_36cf6_level0_row11" class="row_heading level0 row11" >2012-06-01 11:00:00</th>
#       <td id="T_36cf6_row11_col0" class="data row11 col0" >1.566165</td>
#       <td id="T_36cf6_row11_col1" class="data row11 col1" >0.617586</td>
#       <td id="T_36cf6_row11_col2" class="data row11 col2" >0.994653</td>
#       <td id="T_36cf6_row11_col3" class="data row11 col3" >3.178405</td>
#     </tr>
#     <tr>
#       <th id="T_36cf6_level0_row12" class="row_heading level0 row12" >2012-06-01 12:00:00</th>
#       <td id="T_36cf6_row12_col0" class="data row12 col0" >-0.098372</td>
#       <td id="T_36cf6_row12_col1" class="data row12 col1" >0.909400</td>
#       <td id="T_36cf6_row12_col2" class="data

# %% [markdown]
# The residents have decided to implement a community storage, to enhance the utilization of their local generation. The electricity generated from the local renewable energy sources is stored in the battery when generation exceeds the local demand. The stored energy is used when the local generation cannot cover the demand.

# %% [markdown]
# ![T1_RES_case_Bat](Graphics_T1/T1_RES_case_Bat.png)

# %% [markdown]
# **Task 3 Neighbourhood with local RES and Communal Battery
#
# a) Run the following python code that simulates a typical day in the local community with renewable generation and battery storage. For this task the State of charge is 100% in the beginning of the day. The controller acts in the following way: in the case of not enough local generation to cover the demand of the neighbourhood electricity is taken from the battery storage if possible, if this is not possible electricity is taken from the grid. How does the residual load curve change compared to task 2 (the utilization of small scale local renewable generation without storage).
#
# b) Change the State of charge parameter to 50% in the beginning of the day and run the simulation again. Explain how this affects the residual load curve.
#
# c): Change the State of charge parameter to 10% in the beginning of the day and run the simulation again. Explain how this affects the residual load curve.
#
# Note: Changing Objective Controller: Contractual/Physical Limit for connection (Peak shaving & Load Shifting, Load Shedding)
# EV/Flexibilities

# %% [markdown]
# **State of Charge (SOC) of a Battery**: The State of Charge (SOC) of a battery represents the current charge level relative to its full capacity, typically expressed in percentages.  Thus, SOC=100% means the battery is fully charged and SOC=0% means it is fully discharged. To prevent damage the battery has a minimum and maximum SOC (upper and lower boundary) included in the control logic, that cannot be surpassed.

# %%
# %%capture
day_of_year = "2012-06-01"

Components_RES_Bat_case = pd.Series(['Wind', 'PV', 'Load', 'Battery'])

print(Components_RES_Bat_case)
#Input Data Simulation
number_houses = 5    #demand specs

pv_inputs = {'Module_area': 1.26, 'installed_capacity': 500, 'Power_output_at_STC': 250}
# Optional PV inputs with examples: 'NOCT': 44, 'Module_Efficiency': 0.198, 'Irradiance_at_NOCT': 800,
# 'Power_output_at_STC': 250,'peak_power':600, 'm_tilt':14,'m_az':180

wind_inputs = {'p_rated':0.3, 'cp':0.40} # p-rated in kW
#Options for Wind inputs with example values: 'p_rated':300, 'u_rated':10.3, 
# 'u_cutin':2.8, 'u_cutout':25, 'cp':0.40, 'diameter':22, 'output_type':'power'}


battery_inputs = {'initial_soc': 80, 'charge_efficiency': 0.9, 'discharge_efficiency': 0.9, 'soc_min': 10}
#Options for Battery inputs with example values :{'initial_soc': 20, 'max_p': 800, 'min_p': -800, 'max_energy': 800, 'charge_efficiency': 0.9, 
# 'discharge_efficiency': 0.9, 'soc_min': 10, 'soc_max': 90}

Battery_case_simulation = simulation_creator_Balancing(Components_RES_Bat_case,day_of_year,number_houses,pv_inputs, wind_inputs,battery_inputs)
# Out:
# 2024-11-01 16:36:32.392 | INFO     | mosaik.scenario:start:255 - Starting "Controller" as "Controller-0" ...
# 2024-11-01 16:36:32.396 | INFO     | mosaik.scenario:start:255 - Starting "Collector" as "Collector-0" ...
# 2024-11-01 16:36:32.400 | INFO     | mosaik.scenario:start:255 - Starting "CSVB" as "CSVB-0" ...
# 2024-11-01 16:36:33.389 | INFO     | mosaik.scenario:start:255 - Starting "Wind" as "Wind-0" ...
# 2024-11-01 16:36:33.396 | INFO     | mosaik.scenario:start:255 - Starting "CSVB" as "CSVB-1" ...
# 2024-11-01 16:36:34.130 | INFO     | mosaik.scenario:start:255 - Starting "PV" as "PV-0" ...
# 2024-11-01 16:36:34.138 | INFO     | mosaik.scenario:start:255 - Starting "CSVB" as "CSVB-2" ...
# 2024-11-01 16:36:34.980 | INFO     | mosaik.scenario:start:255 - Starting "Load" as "Load-0" ...
# 2024-11-01 16:36:34.987 | INFO     | mosaik.scenario:start:255 - Starting "Battery" as "Battery-0" ...
# 2024-11-01 16:36:34.993 | WARNING  | mosaik.scenario:_check_attributes_values:730 - A connection between persistent and trigger attributes is not recommended.This might cause problems in the simulation!
# 2024-11-01 16:36:34.995 | WARNING  | mosaik.scenario:_check_attributes_values:733 - A connection between non-persistent and non-trigger attributes is not recommended. This might cause problems in the simulation!
# 2024-11-01 16:36:34.998 | INFO     | mosaik.scenario:run:532 - Starting simulation.
# 2024-11-01 16:36:37.224 | INFO     | mosaik.scenario:run:576 - Simulation finished successfully.

# %%
Battery_case_simulation.summarize_results()
# Out:
# <style type="text/css">
# #T_2e2ff_row0_col0, #T_2e2ff_row0_col1, #T_2e2ff_row0_col2, #T_2e2ff_row0_col3, #T_2e2ff_row0_col4, #T_2e2ff_row0_col5, #T_2e2ff_row0_col6, #T_2e2ff_row0_col7, #T_2e2ff_row1_col0, #T_2e2ff_row1_col1, #T_2e2ff_row1_col2, #T_2e2ff_row1_col3, #T_2e2ff_row1_col4, #T_2e2ff_row1_col5, #T_2e2ff_row1_col6, #T_2e2ff_row1_col7, #T_2e2ff_row2_col0, #T_2e2ff_row2_col1, #T_2e2ff_row2_col2, #T_2e2ff_row2_col3, #T_2e2ff_row2_col4, #T_2e2ff_row2_col5, #T_2e2ff_row2_col6, #T_2e2ff_row2_col7, #T_2e2ff_row3_col0, #T_2e2ff_row3_col1, #T_2e2ff_row3_col2, #T_2e2ff_row3_col3, #T_2e2ff_row3_col4, #T_2e2ff_row3_col5, #T_2e2ff_row3_col6, #T_2e2ff_row3_col7, #T_2e2ff_row4_col0, #T_2e2ff_row4_col1, #T_2e2ff_row4_col2, #T_2e2ff_row4_col3, #T_2e2ff_row4_col4, #T_2e2ff_row4_col5, #T_2e2ff_row4_col6, #T_2e2ff_row4_col7, #T_2e2ff_row5_col0, #T_2e2ff_row5_col1, #T_2e2ff_row5_col2, #T_2e2ff_row5_col3, #T_2e2ff_row5_col4, #T_2e2ff_row5_col5, #T_2e2ff_row5_col6, #T_2e2ff_row5_col7, #T_2e2ff_row6_col0, #T_2e2ff_row6_col1, #T_2e2ff_row6_col2, #T_2e2ff_row6_col3, #T_2e2ff_row6_col4, #T_2e2ff_row6_col5, #T_2e2ff_row6_col6, #T_2e2ff_row6_col7, #T_2e2ff_row7_col0, #T_2e2ff_row7_col1, #T_2e2ff_row7_col2, #T_2e2ff_row7_col3, #T_2e2ff_row7_col4, #T_2e2ff_row7_col5, #T_2e2ff_row7_col6, #T_2e2ff_row7_col7, #T_2e2ff_row8_col0, #T_2e2ff_row8_col1, #T_2e2ff_row8_col2, #T_2e2ff_row8_col3, #T_2e2ff_row8_col4, #T_2e2ff_row8_col5, #T_2e2ff_row8_col6, #T_2e2ff_row8_col7, #T_2e2ff_row9_col0, #T_2e2ff_row9_col1, #T_2e2ff_row9_col2, #T_2e2ff_row9_col3, #T_2e2ff_row9_col4, #T_2e2ff_row9_col5, #T_2e2ff_row9_col6, #T_2e2ff_row9_col7, #T_2e2ff_row10_col0, #T_2e2ff_row10_col1, #T_2e2ff_row10_col2, #T_2e2ff_row10_col3, #T_2e2ff_row10_col4, #T_2e2ff_row10_col5, #T_2e2ff_row10_col6, #T_2e2ff_row10_col7, #T_2e2ff_row11_col0, #T_2e2ff_row11_col1, #T_2e2ff_row11_col2, #T_2e2ff_row11_col3, #T_2e2ff_row11_col4, #T_2e2ff_row11_col5, #T_2e2ff_row11_col6, #T_2e2ff_row11_col7, #T_2e2ff_row12_col0, #T_2e2ff_row12_col1, #T_2e2ff_row12_col2, #T_2e2ff_row12_col3, #T_2e2ff_row12_col4, #T_2e2ff_row12_col5, #T_2e2ff_row12_col6, #T_2e2ff_row12_col7, #T_2e2ff_row13_col0, #T_2e2ff_row13_col1, #T_2e2ff_row13_col2, #T_2e2ff_row13_col3, #T_2e2ff_row13_col4, #T_2e2ff_row13_col5, #T_2e2ff_row13_col6, #T_2e2ff_row13_col7, #T_2e2ff_row14_col0, #T_2e2ff_row14_col1, #T_2e2ff_row14_col2, #T_2e2ff_row14_col3, #T_2e2ff_row14_col4, #T_2e2ff_row14_col5, #T_2e2ff_row14_col6, #T_2e2ff_row14_col7, #T_2e2ff_row15_col0, #T_2e2ff_row15_col1, #T_2e2ff_row15_col2, #T_2e2ff_row15_col3, #T_2e2ff_row15_col4, #T_2e2ff_row15_col5, #T_2e2ff_row15_col6, #T_2e2ff_row15_col7, #T_2e2ff_row16_col0, #T_2e2ff_row16_col1, #T_2e2ff_row16_col2, #T_2e2ff_row16_col3, #T_2e2ff_row16_col4, #T_2e2ff_row16_col5, #T_2e2ff_row16_col6, #T_2e2ff_row16_col7, #T_2e2ff_row17_col0, #T_2e2ff_row17_col1, #T_2e2ff_row17_col2, #T_2e2ff_row17_col3, #T_2e2ff_row17_col4, #T_2e2ff_row17_col5, #T_2e2ff_row17_col6, #T_2e2ff_row17_col7, #T_2e2ff_row18_col0, #T_2e2ff_row18_col1, #T_2e2ff_row18_col2, #T_2e2ff_row18_col3, #T_2e2ff_row18_col4, #T_2e2ff_row18_col5, #T_2e2ff_row18_col6, #T_2e2ff_row18_col7, #T_2e2ff_row19_col0, #T_2e2ff_row19_col1, #T_2e2ff_row19_col2, #T_2e2ff_row19_col3, #T_2e2ff_row19_col4, #T_2e2ff_row19_col5, #T_2e2ff_row19_col6, #T_2e2ff_row19_col7, #T_2e2ff_row20_col0, #T_2e2ff_row20_col1, #T_2e2ff_row20_col2, #T_2e2ff_row20_col3, #T_2e2ff_row20_col4, #T_2e2ff_row20_col5, #T_2e2ff_row20_col6, #T_2e2ff_row20_col7, #T_2e2ff_row21_col0, #T_2e2ff_row21_col1, #T_2e2ff_row21_col2, #T_2e2ff_row21_col3, #T_2e2ff_row21_col4, #T_2e2ff_row21_col5, #T_2e2ff_row21_col6, #T_2e2ff_row21_col7, #T_2e2ff_row22_col0, #T_2e2ff_row22_col1, #T_2e2ff_row22_col2, #T_2e2ff_row22_col3, #T_2e2ff_row22_col4, #T_2e2ff_row22_col5, #T_2e2ff_row22_col6, #T_2e2ff_row22_col7, #T_2e2ff_row23_col0, #T_2e2ff_row23_col1, #T_2e2ff_row23_col2, #T_2e2ff_row23_col3, #T_2e2ff_row23_col4, #T_2e2ff_row23_col5, #T_2e2ff_row23_col6, #T_2e2ff_row23_col7 {
#   background-color: #f9f9f9;
#   border-color: black;
#   border-width: 1px;
#   border-style: solid;
#   color: black;
#   font-family: Arial;
#   text-align: center;
# }
# </style>
# <table id="T_2e2ff">
#   <caption>Hourly Simulation results</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e2ff_level0_col0" class="col_heading level0 col0" >Flow to Battery (kWh)</th>
#       <th id="T_2e2ff_level0_col1" class="col_heading level0 col1" >Residual Load</th>
#       <th id="T_2e2ff_level0_col2" class="col_heading level0 col2" >Dumped Energy</th>
#       <th id="T_2e2ff_level0_col3" class="col_heading level0 col3" >Output Power Battery (kW)</th>
#       <th id="T_2e2ff_level0_col4" class="col_heading level0 col4" >Battery SOC (%)</th>
#       <th id="T_2e2ff_level0_col5" class="col_heading level0 col5" >PV Generation (kW)</th>
#       <th id="T_2e2ff_level0_col6" class="col_heading level0 col6" >Wind Generation (kW)</th>
#       <th id="T_2e2ff_level0_col7" class="col_heading level0 col7" >Load Demand (kW)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >date</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e2ff_level0_row0" class="row_heading level0 row0" >2012-06-01 00:00:00</th>
#       <td id="T_2e2ff_row0_col0" class="data row0 col0" >-0.560000</td>
#       <td id="T_2e2ff_row0_col1" class="data row0 col1" >0.300406</td>
#       <td id="T_2e2ff_row0_col2" class="data row0 col2" >-0.300406</td>
#       <td id="T_2e2ff_row0_col3" class="data row0 col3" >-0.041481</td>
#       <td id="T_2e2ff_row0_col4" class="data row0 col4" >10.000000</td>
#       <td id="T_2e2ff_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_2e2ff_row0_col6" class="data row0 col6" >1.075314</td>
#       <td id="T_2e2ff_row0_col7" class="data row0 col7" >1.935720</td>
#     </tr>
#     <tr>
#       <th id="T_2e2ff_level0_row1" class="row_heading level0 row1" >2012-06-01 01:00:00</th>
#       <td id="T_2e2ff_row1_col0" class="data row1 col0" >-0.560000</td>
#       <td id="T_2e2ff_row1_col1" class="data row1 col1" >0.301353</td>
#       <td id="T_2e2ff_row1_col2" class="data row1 col2" >-0.301353</td>
#       <td id="T_2e2ff_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_2e2ff_row1_col4" class="data row1 col4" >10.000000</td>
#       <td id="T_2e2ff_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_2e2ff_row1_col6" class="data row1 col6" >0.817498</td>
#       <td id="T_2e2ff_row1_col7" class="data row1 col7" >1.678851</td>
#     </tr>
#     <tr>
#       <th id="T_2e2ff_level0_row2" class="row_heading level0 row2" >2012-06-01 02:00:00</th>
#       <td id="T_2e2ff_row2_col0" class="data row2 col0" >-0.131907</td>
#       <td id="T_2e2ff_row2_col1" class="data row2 col1" >-0.058517</td>
#       <td id="T_2e2ff_row2_col2" class="data row2 col2" >0.058517</td>
#       <td id="T_2e2ff_row2_col3" class="data row2 col3" >-0.000000</td>
#       <td id="T_2e2ff_row2_col4" class="data row2 col4" >42.080500</td>
#       <td id="T_2e2ff_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_2e2ff_row2_col6" class="data row2 col6" >0.790373</td>
#       <td id="T_2e2ff_row2_col7" class="data row2 col7" >0.863764</td>
#     </tr>
#     <tr>
#       <th id="T_2e2ff_level0_row3" class="row_heading level0 row3" >2012-06-01 03:00:00</th>
#       <td id="T_2e2ff_row3_col0" class="data row3 col0" >0.332968</td>
#       <td id="T_2e2ff_row3_col1" class="data row3 col1" >-0.007600</td>
#       <td id="T_2e2ff_row3_col2" class="data row3 col2" >0.007600</td>
#       <td id="T_2e2ff_row3_col3" class="data row3 col3" >0.047407</td>
#       <td id="T_2e2ff_row3_col4" class="data row3 col4" >70.000000</td>
#       <td id="T_2e2ff_row3_col5" class="data row3
